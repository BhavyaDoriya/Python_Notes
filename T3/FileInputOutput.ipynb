# %%
f=open("files/1.txt","w")
f.write("HELLO")
f.close()
s
# Out:
# 'HELLOHELLOHELLOHELLOHELLOHELLO'

# %%
f=open("files/2.txt","w")
for i in range(1,11):
    f.write(str(i)+"\n")
    
f.close()

# %%
f=open("files/sample.txt","w")
f.writelines(["THis is nuts","Weirdddddddddddd"])
# f.read() -->error-->the file is opened in w mode so you can not read the file
# w mode overwrites the file
f.close()

# %%
# a mode--> in a mode it appends the text to a file(does not overwrite it)
f=open("files\\1.txt","a")
f.writelines(["abc\n","def\n"])
# f.read()-->can only write
f.close()

# %%
f=open("files/1.txt","r")
print(f.read())
# print(">",f.read()) -->Pointer goes to end of file so it will not give output
f.close()
# Out:
# HELLOabc
# def
# abc
# def

# %%
f=open("files/1.txt","r")
print(f.read(3))
print(f.read(5))#will return output of next 5 digit from 4th position
f.close()
# Out:
# HEL
# LOabc

# %%
f=open("files/1.txt","r")
print(f.readline(),end="")
print(f.readline())
f.close()
# Out:
# HELLOabc
# def

# %%
f=open("files/1.txt","r")
print(f.readline(5),end="")
print(f.readline())
f.close()
# Out:
# HELLOabc

# %%
f=open("files/1.txt","r")
print(f.readlines())
f.close()
# Out:
# ['HELLOabc\n', 'def\n', 'abc\n', 'def\n']

# %%
f=open("files/1.txt","r")
print(f.readlines(3))
print(f.readlines(8))
f.close()
# Out:
# ['HELLOabc\n']
# ['def\n', 'abc\n', 'def\n']

# %%
f=open("files/3.txt","r+")
print(f.read())
print(f.write("VHA"))
f.close()
# Out:
# WelcomeVHA
# 3

# %%
f=open("files/3.txt","r+")
print(f.write("VHA"))#will start overwriting the file from pointer 0
print(f.read())
f.close()
#r+ or r mode doesn't create new file if file does not exist
# Out:
# 3
# jrgesgr"?
# df
# dvfdfdvmndklvm "
# AS
# c'rgejnkenjmf;.,t\
# dvfs'hjfVHAVHAVHA

# %%
f=open("files/3.txt","w+")
f.write("Welcome")#will delete all previous data and start writing from 0
print(f.read())#will not print anything cause pointer is at end of file
print(f.tell())#will tell current position of the pointer
f.seek(0)#will change the position of pointer\
# seek(offset,position)
# 0-->start , 1-->current,2-->end
print(f.read())
f.close()
# Out:
# 7
# Welcome

# %%
f=open("files/3.txt","a+")
print(f.read())#when you open with a+ mode your cursor moves to end of file by default so it will return empty string
f.close()

# %%
f=open("files/1.txt")
for i in f:
    print(i,end="")
f.close()
# Out:
# HELLOabc
# def
# abc
# def

# %%
# to automatically close file
with open("files/1.txt") as f:
    for i in f:
        print(i,end="")
# Out:
# HELLOabc
# def
# abc
# def

# %%
with open("files/1.txt") as f:
    print(f.name)
    print(f.mode)
    print(f.closed)
    print(f.readable())
    print(f.writable())
# Out:
# files/1.txt
# r
# False
# True
# False

# %%
f=open("fileBySir/secretmessage.txt",encoding="utf-8")
count1=1
for i in f:
    
    if count1>5:
        user=input("Read more?")
        if(user.lower()=="yes"):
            count1=1
        else:
            break
    else:
        print(i)
        count1+=1
        
    
f.close()
# Out:
# Every day is an opportunity to learn something new.
#
# Venturing into the unknown can be both exciting and scary.
#
# Even in the darkest of times, hope can still shine through.
#
# Nothing is impossible if you set your mind to it.
#
# A journey of a thousand miles begins with a single step.
#
# Read more?yes
# Only through persistence can we overcome life's obstacles.
#
# Nothing worth having comes easy, but it's always worth the effort.
#
# Kindness is a language that the deaf can hear and the blind can see.
#
# Every moment spent with loved ones is a treasure.
#
# You are capable of achieving great things if you believe in yourself.
#
# Read more?yes
# A journey of a thousand miles starts with a single step.
#
# Love is the most powerful force in the world.
#
# Life is not measured by the breaths we take, but by the moments that take our breath away.
#
# Success is not final, failure#猿も木から落ちる, is not fatal: It is the courage to continue that counts.
#
# ...
